# %% [markdown]
# ### Code and Data

# %%
def kurtosis(x):
    n = len(x)
    mean_x = sum(x) / n
    return (
        sum((xi - mean_x) ** 4 for xi in x)
        / n
        / (sum((xi - mean_x) ** 2 for xi in x) / n) ** 2
    )
